# %%
from core import PriceSeries, PortfolioOptimizer
from data.gathering import download_historical_fin_data, download_bankier_articles
# %matplotlib inline

# %%
stock = PriceSeries('CDR')

# %%
stock.summary()
# Out:
# first_day         1994-08-02
# last_day          2018-02-02
# n_observations          5832
# ret_1d            -0.0140107
# ret_5d            -0.0122701
# ret_21d             0.145954
# ret_252d            0.673829
# ret_3y                 1.606
# ret_5y               1.96971
# std_5d             0.0146993
# std_21d            0.0275145
# std_252d           0.0235091
# std_252d_ann        0.373195
# return/risk_1y       1.80557
# dtype: object

# %%
portfolio = PortfolioOptimizer('Portfolio1')

# %%
stocks = stocks = ['CDR', 'PZU', 'CCC', '11B', 'KGH']

# %%
portfolio.add_stocks(stocks)

# %%
portfolio.correlation(plot=True)
# Out:
#           CDR       PZU       CCC       11B       KGH
# CDR  1.000000  0.051327  0.288835  0.142575  0.261437
# PZU  0.051327  1.000000  0.254895 -0.145570  0.352951
# CCC  0.288835  0.254895  1.000000 -0.067667  0.459128
# 11B  0.142575 -0.145570 -0.067667  1.000000  0.059017
# KGH  0.261437  0.352951  0.459128  0.059017  1.000000

# %%
portfolio.summary()
# Out:
#                        CDR         PZU         CCC         11B         KGH
# first_day       1994-08-02  2010-05-12  2004-12-02  2010-10-28  1997-07-10
# last_day        2018-02-02  2018-02-02  2018-02-02  2018-02-02  2018-02-02
# n_observations        5832        1935        3282        1809        5151
# ret_1d          -0.0140107  -0.0152849 -0.00356507 -0.00706717  -0.0272744
# ret_5d          -0.0122701  -0.0845947  -0.0371581   -0.011751  -0.0357585
# ret_21d           0.145954  -0.0339016   -0.045383   0.0434851  -0.0415222
# ret_252d          0.673829    0.242526    0.313098     0.39138   -0.123888
# ret_3y               1.606    0.409646    0.832245    0.892233     0.68635
# ret_5y             1.96971   0.0348533    0.643201     1.09507   0.0938348
# std_5d           0.0146993   0.0123215  0.00953762  0.00371689   0.0170275
# std_21d          0.0275145   0.0138092   0.0155129   0.0163598   0.0106702
# std_252d         0.0235091   0.0148913   0.0185161   0.0218197   0.0190052
# std_252d_ann      0.373195    0.236391    0.293933    0.346377    0.301699
# return/risk_1y     1.80557     1.02595      1.0652     1.12993   -0.410636

# %%
portfolio.generate_rand_portfolios(n_portfolios=10000, months_of_data=36,only_plot=True)

# %%
fin_data = download_historical_fin_data('11BIT','q')

# %%
fin_data.tail()
# Out:
#           # of shares  Operational profit (loss)  Net profit (loss)   Equity  \
# date
# 2016-III     2217.199                     2234.0             1335.0  36360.0
# 2016-IV      2217.199                     4566.0             5470.0  42126.0
# 2017-I       2217.199                      370.0            -1053.0  41060.0
# 2017-II      2287.199                     2555.0             1464.0  43076.0
# 2017-III     2287.199                     -672.0             -830.0  42246.0
#
#           Net revenues  Gross profit (loss)  Book value / share  Profit/share  \
# date
# 2016-III        5226.0               1699.0              16.399         0.602
# 2016-IV         9506.0               6193.0              18.999         2.467
# 2017-I          2907.0               -857.0              18.519        -0.475
# 2017-II         5797.0               1476.0              18.834         0.640
# 2017-III        2733.0              -1001.0              18.471        -0.363
#
#            Assets  Depreciation  EBITDA
# date
# 2016-III  38821.0         446.0  2680.0
# 2016-IV   45649.0         636.0  5202.0
# 2017-I    42992.0         486.0   856.0
# 2017-II   45053.0         453.0  3008.0
# 2017-III  44481.0         408.0  -264.0

# %%
fin_data['Net profit (loss)'].plot(kind='bar')

# %%
articles = download_bankier_articles('11BIT')
# Out:
# 1 of 101 downloaded
# 2 of 101 downloaded
# 3 of 101 downloaded
# 4 of 101 downloaded
# 5 of 101 downloaded
# 6 of 101 downloaded
# 7 of 101 downloaded
# 8 of 101 downloaded
# 9 of 101 downloaded
# 10 of 101 downloaded
# 11 of 101 downloaded
# 12 of 101 downloaded
# 13 of 101 downloaded
# 14 of 101 downloaded
# 15 of 101 downloaded
# 16 of 101 downloaded
# 17 of 101 downloaded
# 18 of 101 downloaded
# 19 of 101 downloaded
# 20 of 101 downloaded
# 21 of 101 downloaded
# 22 of 101 downloaded
# 23 of 101 downloaded
# 24 of 101 downloaded
# 25 of 101 downloaded
# 26 of 101 downloaded
# 27 of 101 downloaded
# 28 of 101 downloaded
# 29 of 101 downloaded
# 30 of 101 downloaded
# 31 of 101 downloaded
# 32 of 101 downloaded
# 33 of 101 downloaded
# 34 of 101 downloaded
# 35 of 101 downloaded
# 36 of 101 downloaded
# 37 of 101 downloaded
# 38 of 101 downloaded
# 39 of 101 downloaded
# 40 of 101 downloaded
# 41 of 101 downloaded
# 42 of 101 downloaded
# 43 of 101 downloaded
# 44 of 101 downloaded
# 45 of 101 downloaded
# 46 of 101 downloaded
# 47 of 101 downloaded
# 48 of 101 downloaded
# 49 of 101 downloaded
# 50 of 101 downloaded
# 51 of 101 downloaded
# 52 of 101 downloaded
# 53 of 101 downloaded
# 54 of 101 downloaded
# 55 of 101 downloaded
# 56 of 101 downloaded
# 57 of 101 downloaded
# 58 of 101 downloaded
# 59 of 101 downloaded
# 60 of 101 downloaded
# 61 of 101 downloaded
# 62 of 101 downloaded
# 63 of 101 downloaded
# 64 of 101 downloaded
# 65 of 101 downloaded
# 66 of 101 downloaded
# 67 of 101 downloaded
# 68 of 101 downloaded
# 69 of 101 downloaded
# 70 of 101 downloaded
# 71 of 101 downloaded
# 72 of 101 downloaded
# 73 of 101 downloaded
# 74 of 101 downloaded
# 75 of 101 downloaded
# 76 of 101 downloaded
# 77 of 101 downloaded
# 78 of 101 downloaded
# 79 of 101 downloaded
# 80 of 101 downloaded
# 81 of 101 downloaded
# 82 of 101 downloaded
# 83 of 101 downloaded
# 84 of 101 downloaded
# 85 of 101 downloaded
# 86 of 101 downloaded
# 87 of 101 downloaded
# 88 of 101 downloaded
# 89 of 101 downloaded
# 90 of 101 downloaded
# 91 of 101 downloaded
# 92 of 101 downloaded
# 93 of 101 downloaded
# 94 of 101 downloaded
# 95 of 101 downloaded
# 96 of 101 downloaded
# 97 of 101 downloaded
# 98 of 101 downloaded
# 99 of 101 downloaded
# 100 of 101 downloaded
# 101 of 101 downloaded

# %%
len(articles)
# Out:
# 101

# %%
articles[1][:3]
# Out:
# ['2015-02-12 16:42',
#  '11 bit studios spodziewa się, że większość przychodów z TWoM dopiero przed spółką',
#  '11 bit studios, dla którego IV kw. 2014 r. był najlepszy w historii dzięki bardzo dobrej sprzedaży gry This War of Mine, spodziewa się, że zdecydowana większość przychodów ze sprzedaży tej gry będzie zrealizowana w przyszłości - poinformował na spotkaniu z inwestorami prezes spółki Grzegorz Miechowski. "Spodziewam się, że zdecydowana większość przychodów z gry This War of Mine dopiero przed nami. Uważam tak, gdyż analizując dane historyczne np. dla gry Anomaly Warzone Earth, pierwsze tygodnie sprzedaży wygenerowały przychody stanowiące mniej niż 10 proc. łącznych przychodów z gry" - powiedział Miechowski. "Dodatkowo nadal widzimy bardzo dobrą sprzedaż na Steamie, mimo że nie było do tej pory żadnych promocji. Ważne też będzie rozwijanie samej gry - zespół w tej chwili pracuje nad nowymi atrakcjami dla graczy. Chcemy, aby cykl życia tej gry był jak najdłuższy" - dodał. Gra This War of Mine miała premierę 14 listopada 2014 r. Jak poinformował Miechowski, koszty produkcji gry zwróciły się po pierwszym weekendzie po premierze. W jego ocenie duży potencjał będzie miała także mobilna wersja gry. "Wydaje się, że potencjał wersji mobilnej może być porównywalny z grą na PC. Wersja mobilna planowana jest około drugiego kwartału" - powiedział prezes. W 2015 r. 11 bit studios planuje też dużą premierę gry związaną z This War of Mine. W IV kw. 2014 r. 11 bit studios osiągnęło 10,9 mln zł zysku netto, 13,25 mln zł zysku operacyjnego 13,3 mln zł EBITDA, i 14,83 mln zł przychodów. Na koniec roku spółka miała 7,7 mln zł środków pieniężnych i 7,3 mln zł w należnościach krótkoterminowych. Miechowski poinformował, że pomimo dobrych wyników finansowych i posiadania gotówki spółka nie powinna wypłacać dywidendy za 2014 r. i przeznaczać nadwyżki na rozwój. W planach na 2015 r. spółka ma m.in. wydanie gry pod roboczym tytułem Industrials. "Moim zdaniem do będzie gra o dużym potencjale komercyjnym, większym niż This War of Mine. Premierę zakładamy w czwartym kwartale" - powiedział Miechowski. Plany na 2015 r. przewidują też rozwój internetowej platformy do sprzedaży gier cyfrowych Games od Republic, która ma obecnie w katalogu ponad 500 tytułów, a także dalszy rozwój 11 bit launchpad, który wydaje pozycje innych producentów.(PAP) gsu/ osz/']
